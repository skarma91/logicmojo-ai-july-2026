# %% [markdown]
# # Micro-assignment 4.4: retrieval over a movie-plot corpus
#
# Real movie plots (`data/movies.jsonl`), transformer embeddings (`all-MiniLM-L6-v2`) + FAISS, exactly as in class. See README.md for the five problems. The embedding cells need internet on first run.

# %% [markdown]
# ## Setup
#
# ```
# pip install sentence-transformers faiss-cpu rank-bm25 numpy
# ```

# %%
# Given: load the movie corpus.

import json, numpy as np
rows = [json.loads(l) for l in open("data/movies.jsonl")]
ids = [r["id"] for r in rows]
plots = [r["plot"] for r in rows]
print(len(rows), "movies loaded")

# %% [markdown]
# ### 1. Chunk a page
# Word-window chunker (size 20, overlap 5) on the first three plots joined; print words, chunks, overlap check.

# %%
# your code here

# %% [markdown]
# ### 2. Embed with a transformer and search with FAISS
# Encode plots with all-MiniLM-L6-v2, build a FAISS IndexFlatIP, write search(query, k).

# %%
# your code here

# %% [markdown]
# ### 3. Metadata filter
# Write search_filtered(query, year, k) (over-fetch then filter); show the remake year filter picks the 2003 version.

# %%
# your code here

# %% [markdown]
# ### 4. Hybrid: meaning plus keywords
# Add a BM25 keyword baseline and a min-max blend; show keyword-only ranks the wrong film while the blend recovers.

# %%
# your code here

# %% [markdown]
# ### 5. Why meaning wins (reasoning)
# Show the dense search finds Inception for 'the one about the dream heist' where BM25 does not, and explain why.

# %%
# your code here
