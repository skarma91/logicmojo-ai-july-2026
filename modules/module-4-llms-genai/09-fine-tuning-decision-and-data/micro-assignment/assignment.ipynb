# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/skarma91/logicmojo-ai-july-2026/blob/main/modules/module-4-llms-genai/09-fine-tuning-decision-and-data/micro-assignment/assignment.ipynb)
#
# # Micro-assignment 4.9: a house-style SFT dataset for movies
#
# Prepare a small supervised fine-tuning dataset that teaches a **house style** on
# the movie track: answer a plot description with the film as `Title (Year)` plus one
# spoiler-free line (and a fixed refusal when unknown). This teaches a behavior, not
# facts. See README.md for the five problems. A reference solution is in `solution/`.

# %% [markdown]
# ## Problems
#
# 1. Write the house-style `SYSTEM` rule (Title (Year) + one spoiler-free line; a fixed refusal).
# 2. Write `to_rows(pairs)` that turns `(description, target)` pairs into chat-format rows (system, user, assistant).
# 3. Inspect: print the example count and one formatted example.
# 4. Split the rows into train and validation.
# 5. Reasoning: justify why fine-tuning (not RAG or prompting) fits this, and name one risk.

# %%
# 1. SYSTEM = ...
# your code here

# %%
# 2. PAIRS = [(description, target), ...]  and  to_rows(pairs)
# your code here

# %%
# 3. inspect: count + one formatted example
# your code here

# %%
# 4. train/validation split
# your code here

# %% [markdown]
# ## 5. Justification and one risk (reasoning)
#
# _Write two to four sentences: why fine-tuning beats RAG and prompting for this
# behavior, and one risk to watch (for example, train/eval overlap, or letting facts
# leak into the targets)._
