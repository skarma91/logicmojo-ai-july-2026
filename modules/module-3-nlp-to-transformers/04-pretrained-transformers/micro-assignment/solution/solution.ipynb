# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/skarma91/logicmojo-ai-july-2026/blob/main/modules/module-3-nlp-to-transformers/04-pretrained-transformers/micro-assignment/solution/solution.ipynb)
#
# # Micro-assignment 3.4 solution: Using pretrained transformers
#
# Reference solution. These run without any download, so you can check them offline.

# %% [markdown]
# ### Problem 1: Task to pipeline name

# %%
mapping = {"sentiment": "sentiment-analysis",
           "generate": "text-generation",
           "embed": "feature-extraction"}
tasks = ["sentiment", "embed"]
print([mapping[t] for t in tasks])
# Out:
# ['sentiment-analysis', 'feature-extraction']

# %% [markdown]
# ### Problem 2: Why load the matching tokenizer

# %%
print("the model learned what each token id means; a mismatched tokenizer assigns different "
      "ids, so the input is meaningless to the model. Load the tokenizer and model by the same name")
# Out:
# the model learned what each token id means; a mismatched tokenizer assigns different ids, so the input is meaningless to the model. Load the tokenizer and model by the same name

# %% [markdown]
# ### Problem 3: A padded batch's shape

# %%
lengths = [4, 6, 5]                 # token counts of three inputs
n, max_len = len(lengths), max(lengths)
print("batch shape:", (n, max_len))
# Out:
# batch shape: (3, 6)

# %% [markdown]
# ### Problem 4: Inference settings

# %%
print("model.eval() and torch.no_grad(): eval switches layers like dropout to scoring mode, "
      "and no_grad skips gradient tracking for a faster forward pass")
# Out:
# model.eval() and torch.no_grad(): eval switches layers like dropout to scoring mode, and no_grad skips gradient tracking for a faster forward pass

# %% [markdown]
# ### Problem 5: Tokens vs words (a quick sanity check)

# %%
s = "the cat sat"
print("words:", len(s.split()))
# Out:
# words: 3

# %% [markdown]
# ### Problem 6: Why use a pretrained model

# %%
print("pretrained models already learned language from huge corpora, so you get strong "
      "results without the data, compute, or time to train one yourself")
# Out:
# pretrained models already learned language from huge corpora, so you get strong results without the data, compute, or time to train one yourself
